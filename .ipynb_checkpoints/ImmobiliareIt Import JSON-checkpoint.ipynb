# %% [markdown]
# # Houseprices for Italian Listings on Immobiliare.it

# %% [markdown]
# ## Luca Verginer

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import re
import json
import datetime
import dateutil

# %%
# %matplotlib inline

# %%
# for extracting the area
re_area = re.compile("\s*(\d+)\s+")

# %%
plt.matplotlib.style.available
# Out:
# ['dark_background',
#  'seaborn-pastel',
#  'seaborn-bright',
#  'seaborn-talk',
#  'classic',
#  'seaborn-dark-palette',
#  'seaborn-white',
#  'seaborn-colorblind',
#  'fivethirtyeight',
#  'seaborn-ticks',
#  'seaborn-muted',
#  'seaborn-dark',
#  'ggplot',
#  'seaborn-darkgrid',
#  'seaborn-notebook',
#  'seaborn-whitegrid',
#  'grayscale',
#  'bmh',
#  'seaborn-paper',
#  'seaborn-deep',
#  'seaborn-poster']

# %%
plt.matplotlib.style.use('ggplot')

# %%
def correctScrapyJSONOutput(inputLine, querylocation):
    outputLine = {}
    outputLine['querylocation'] = querylocation
    
    if len(inputLine['area'])==0:
        outputLine['area'] = 'NaN'
    else:
        area = re_area.match(inputLine['area'][0]).groups()[0]
        outputLine['area'] = area
    
    if len(inputLine['bathrooms']) == 0:
        outputLine['bathrooms'] = "NaN"
    else:
        outputLine['bathrooms'] = inputLine['bathrooms'][0].strip()
    
    try:
        outputLine['bathrooms'] =  int(outputLine['bathrooms'])
    except:
        outputLine['bathrooms'] = 4
    
    outputLine['contract'] = inputLine['contract'][0]
    outputLine['description'] = inputLine['description']
    
    if len(inputLine['energyClass']) == 0:
        outputLine['energyClass'] = "NaN"
    else:
        outputLine['energyClass'] = inputLine['energyClass'][0]
    
    if len(inputLine['gardenQ']) == 0:
        outputLine['gardenQ'] = "NaN"
    else:
        outputLine['gardenQ'] = inputLine['gardenQ'][0]
    outputLine['address'] = inputLine['address']
    outputLine['listingDate'] = dateutil.parser.parse(inputLine['listingDate'][0])
    outputLine['price'] = float(inputLine["price"][0].replace(".",""))
    outputLine['url'] = inputLine['url']
    return outputLine

# %%
def importScrapyCSV(filePath, query, maxLines=100000):
    num_lines = sum(1 for line in open(filePath))
    outputList = []
    with open(filePath, 'r') as scrapyJsonFile:
        for i, line in enumerate(scrapyJsonFile):
            if i > maxLines:
                break
            if i==0:
                line = json.loads(line[1:-2])
            elif i==num_lines-1:
                line = json.loads(line[:-1])
            else:
                # for badly put together json
                if "][" in line:
                    badLines = line.split('][')
                    badLine1 = json.loads(badLines[0])
                    badLine2 = json.loads(badLines[1][:-2])
                    outputList.append(correctScrapyJSONOutput(badLine1,query))
                    outputList.append(correctScrapyJSONOutput(badLine2,query))
                    continue
                line = json.loads(line[:-2])
            outputList.append(correctScrapyJSONOutput(line,query))
    return outputList

# %%
milanoDict = importScrapyCSV('./scrapes/milano.json','Milano')
luccaDict = importScrapyCSV('./scrapes/lucca.json','Lucca')
bolzanoDict = importScrapyCSV('./scrapes/bolzano.json','Bolzano')
trentoDict = importScrapyCSV('./scrapes/trento.json','Trento')
firenzeDict = importScrapyCSV('./scrapes/firenze.json','Firenze')
romaDict = importScrapyCSV('./scrapes/roma.json','Roma',10733)

# %%
dtaFrame = pd.DataFrame(milanoDict)
dtaFrame = dtaFrame.append(luccaDict)
dtaFrame = dtaFrame.append(bolzanoDict)
dtaFrame = dtaFrame.append(trentoDict)
dtaFrame = dtaFrame.append(firenzeDict)
dtaFrame = dtaFrame.append(romaDict)

# %%
dtaFrame
# Out:
#                                                  address area  bathrooms  \
# 0      [Via Alessandro Astesani, Milano, Zona: Affori...  164          3
# 1      [Via Giuseppe Pecchio 20, Milano, Zona: Città ...  140          2
# 2      [Via Giulio Cesare Procaccini 1, Milano, Zona:...   66          1
# 3      [Via Marco Fabio Quintiliano 5, Milano, Zona: ...   55          1
# 4      [via Copernico, Milano, Zona: Centrale, Repubb...  135          2
# 5      [Via Marco Fabio Quintiliano 5, Milano, Zona: ...  114          2
# 6      [viale Gran Sasso, Milano, Zona: Città Studi, ...  270          3
# 7      [Viale Omero, Milano, Zona: Missaglia, Gratoso...   55          1
# 8      [Viale Lunigiana 4, Milano, Zona: Monza-Maggio...   77          1
# 9      [Via Alessandro Astesani 56, Milano, Zona: Aff...   86          1
# 10     [Via Alessandro Astesani 47, Milano, Zona: Aff...  113          2
# 11     [Via Alessandro Astesani 47, Milano, Zona: Aff...  122          2
# 12     [piazza XXV Aprile, Milano, Zona: Centro - Mos...   65          1
# 13     [Via Edoardo Bassini, Milano, Zona: Città Stud...   97          1
# 14     [Viale Corsica 45, Milano, Zona: Città Studi, ...   55          1
# 15     [Brenta, Milano, Zona: Lodi, Brenta, Molise, M...   35          1
# 16     [Via S.M.Valle, 3a, Milano, Zona: Duomo, Brera...  115          2
# 17     [via Vallazze, Milano, Zona: Città Studi, Piol...   70          1
# 18     [Via Giuseppe Piolti de' Bianchi 48, Milano, Z...  150          2
# 19     [Via Alberto da Giussano, Milano, Zona: Sempio...  300          4
# 20     [via Bruno Maderna, Milano, Zona: Mecenate, Sa...   65          1
# 21     [Via Garigliano 7, Milano, Zona: Isola, Stazio...   75          1
# 22     [Piazza Enrico Bottini, Milano, Zona: Città St...  140          2
# 23     [Via Carnia, Milano, Zona: Lambrate, Ortica, P...   90          2
# 24     [via Garofalo, Milano, Zona: Città Studi, Piol...  190          2
# 25     [via Ferrucci, Milano, Zona: Sempione - Fiera ...  150          2
# 26     [Piazzale Ferdinando Martini, Milano, Zona: Lo...   60          1
# 27     [via Macedonio Melloni, Milano, Zona: Indipend...  124          2
# 28     [Piazza Guglielmo Oberdan, Milano, Zona: Indip...  115          2
# 29     [Via Tito Livio 21, Milano, Zona: Lodi, Brenta...   70          1
# ...                                                  ...  ...        ...
# 10704  [Piazza Antonio Mancini 4, Roma, Zona: Flamini...   80          1
# 10705  [via agostino scali, Roma, Zona: Giustiniana, ...   40          1
# 10706  [Via Veientana 5, Roma, Zona: Cassia, Tomba di...   65          1
# 10707  [Via Giorgio Vigolo 12, Roma, Zona: EUR, Torri...  102          2
# 10708  [via Cristofaro Landino, Roma, Zona: Monte Sac...  130          2
# 10709  [Via Montefiorino, Roma, Zona: Prima Porta, Qu...   70          1
# 10710  [Viale Tito Livio, Roma, Zona: Balduina, Monte...  150          2
# 10711  [Via Monterosi, Roma, Zona: Fleming, Vigna Cla...  160          2
# 10712  [Via Francesco Valagussa, Roma, Zona: Gianicol...  167          1
# 10713  [via Francesco Saverio Sprovieri, Roma, Zona: ...   90          2
# 10714  [Via della Palmarola Nuova, Roma, Zona: Pineta...  130          1
# 10715  [Via Tassullo, Roma, Zona: Infernetto, Castel ...  130          2
# 10716  [circonvallazione ostiense, Roma, Zona: Garbat...   90          1
# 10717  [Via Calcinaia, Roma, Zona: Tufello, Nuovo Sal...  300          3
# 10718  [Via Giuseppe Rovani, Roma, Zona: Monte Sacro,...  180          2
# 10719  [Viale della Grande Muraglia 233, Roma, Zona: ...  170          3
# 10720  [via santa bernadette, Roma, Zona: Aurelio, Bo...  128          2
# 10721  [Via Baccina, Roma, Zona: Centro Storico, Quar...   55          1
# 10722  [Via Camerata Picena 379, Roma, Zona: Fidene, ...  115          2
# 10723  [Via Quinto Publicio 31, Roma, Zona: Cinecittà...   60          1
# 10724  [Viale Tirreno, Roma, Zona: Tufello, Nuovo Sal...  115          1
# 10725  [via del Babuino, Roma, Zona: Centro Storico, ...  110          2
# 10726  [Via Amantea, Roma, Zona: Quarto Miglio, Statu...  140          2
# 10727  [via Francesco Denza, Roma, Zona: Flaminio, Pa...  220          3
# 10728  [via delle robinie, Roma, Zona: Centocelle, Al...   75          1
# 10729  [Via Nomentana 972, Roma, Zona: Monte Sacro, T...  120          2
# 10730  [via Bernardo Pasquini, Roma, Zona: Infernetto...  180          2
# 10731  [Via Rosetta Pampanini 1107, Roma, Zona: Fiden...  100          2
# 10732  [via Giuseppe Troiani, Roma, Zona: Portuense, ...   80          2
# 10733  [Via Alessandro Torlonia, Roma, Zona: Bologna,...  230          3
#
#       contract                                        description energyClass  \
# 0      Vendita                                  Milano-Affori FNM           A
# 1      Vendita  "Via Pecchio - P.zza Aspromonte: Vendesi affas...           G
# 2      Vendita         LANCIO COMMERCIALE 2° LOTTO 27-28 FEBBRAIO           A
# 3      Vendita  Proponiamo in vendita, in contesto di nuova co...           A
# 4      Vendita  Rif: Copernico 135 - In Palazzo Signorile con ...           F
# 5      Vendita  Proponiamo in vendita, in contesto di nuova co...           A
# 6      Vendita  Rif: DSZ17 - Milano, Viale Gran Sasso, nelle i...           F
# 7      Vendita  immobiliare.gng@fastwebnet.it - viale omero. c...           F
# 8      Vendita  M3 SONDRIO - In stabile civile anni '50 ben ab...           F
# 9      Vendita                                      Milano-Affori           A
# 10     Vendita                                      Milano-Affori           A
# 11     Vendita                                     Milano Affori            A
# 12     Vendita  Rif: XXV Aprile 65 - In Palazzo d'Epoca dei pr...           F
# 13     Vendita  In Via Bassini, in condominio signorile con se...           G
# 14     Vendita  Cerchi un bilocale da personalizzare in un con...           G
# 15     Vendita  immobiliare.gng@fastwebnet.it - zona corso lod...           D
# 16     Vendita  In uno stabile signorile del 1970, in pieno ce...           G
# 17     Vendita  Rif: B17DRX - Rif. B17DRX Città Studi, zona Po...           E
# 18     Vendita  Nei pressi di Corso Plebisciti, dove sorgerà l...           G
# 19     Vendita  Esclusivo attico in meraviglioso contesto d'ep...          A+
# 20     Vendita           - 2 Locali con Ampio Terrazzo di 40 mq:            G
# 21     Vendita  Nell'affascinante quartiere Isola, a ridosso d...           G
# 22     Vendita  A pochi passi dalla MM di Milano Lambrate prop...           F
# 23     Vendita  M2 UDINE//VIA CARNIA// Proponiamo in palazzina...           G
# 24     Vendita  Rif: Piola 190 - In Palazzo d'Epoca Vendiamo A...           F
# 25     Vendita  Rif: T522I - Via Giovanni da Procida - MM Domo...           G
# 26     Vendita  immobiliare.gng@fastwebnet.it - piazzale ferdi...           G
# 20     http://www.immobiliare.it/50067359-Vendita-Bil...
# 21     http://www.immobiliare.it/54609336-Vendita-Tri...
# 22     http://www.immobiliare.it/53113473-Vendita-Qua...
# 23     http://www.immobiliare.it/53237165-Vendita-Tri...
# 24     http://www.immobiliare.it/43840020-Vendita-App...
# 25     http://www.immobiliare.it/53047345-Vendita-Vil...
# 26     http://www.immobiliare.it/54967576-Vendita-Bil...
# 27     http://www.immobiliare.it/46263739-Vendita-Qua...
# 28     http://www.immobiliare.it/51830021-Vendita-Qua...
# 29     http://www.immobiliare.it/52069791-Vendita-Bil...
# ...                                                  ...
# 10704  http://www.immobiliare.it/45870968-Vendita-Tri...
# 10705  http://www.immobiliare.it/47372047-Vendita-Bil...
# 10706  http://www.immobiliare.it/47466309-Vendita-Cas...
# 10707  http://www.immobiliare.it/47573449-Vendita-Tri...
# 10708  http://www.immobiliare.it/48100207-Vendita-Qua...
# 10709  http://www.immobiliare.it/49273843-Vendita-Bil...
# 10710  http://www.immobiliare.it/49298403-Vendita-App...
# 10711  http://www.immobiliare.it/49739393-Vendita-App...
# 10712  http://www.immobiliare.it/49833077-Vendita-Att...
# 10713  http://www.immobiliare.it/50059121-Vendita-Tri...
# 10714  http://www.immobiliare.it/50320895-Vendita-Qua...
# 10715  http://www.immobiliare.it/50390903-Vendita-Vil...
# 10716  http://www.immobiliare.it/50607485-Vendita-Bil...
# 10717  http://www.immobiliare.it/50740135-Vendita-Vil...
# 10718  http://www.immobiliare.it/50893507-Vendita-Att...
# 10719  http://www.immobiliare.it/50927495-Vendita-Att...
# 10720  http://www.immobiliare.it/51376647-Vendita-Qua...
# 10721  http://www.immobiliare.it/51512123-Vendita-Bil...
# 10722  http://www.immobiliare.it/51522881-Quadrilocal...
# 10723  http://www.immobiliare.it/51687335-Vendita-Bil...
# 10724  http://www.immobiliare.it/51875551-Vendita-Qua...
# 10725  http://www.immobiliare.it/52023029-Vendita-Att...
# 10726  http://www.immobiliare.it/52030311-Vendita-Qua...
# 10727  http://www.immobiliare.it/52130903-Vendita-App...
# 10728  http://www.immobiliare.it/52401437-Vendita-Tri...
# 10729  http://www.immobiliare.it/52418779-Vendita-Qua...
# 10730  http://www.immobiliare.it/51099019-Vendita-Vil...
# 10731  http://www.immobiliare.it/54699266-Vendita-Tri...
# 10732  http://www.immobiliare.it/54063172-Vendita-Tri...
# 10733  http://www.immobiliare.it/53723590-Vendita-App...
#
# [31134 rows x 11 columns]

# %%
plt.subplot
plt.subplot(1, 2, 1)
plt.hist(dtaFrame[(dtaFrame.price > 10000) & (dtaFrame.querylocation == 'Lucca')].price, bins=40);
plt.subplot(1, 2, 2)
plt.hist(dtaFrame[(dtaFrame.price > 10000) & (dtaFrame.querylocation == 'Bolzano')].price, bins=40);

# %%
plt.hist(dtaFrame[(dtaFrame.price > 10000) & (dtaFrame.querylocation == 'Bolzano')].price, bins=40);

# %%
plt.hist(dtaFrame[(dtaFrame.price > 8000) & (dtaFrame.querylocation == 'Firenze')].price, bins=40);

# %%
plt.hist(dtaFrame[(dtaFrame.price > 8000) & (dtaFrame.querylocation == 'Bolzano')].price, bins=40);

# %%
location = "Trento"
plt.hist(dtaFrame[(dtaFrame.price > 8000) & (dtaFrame.querylocation == location)].price, bins=40);
